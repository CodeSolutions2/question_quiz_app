# %% [markdown]
# # Etudier pour des exams
#
# Exam URL: https://www.linkedin.com/skill-assessments/Python%20(Programming%20Language)/quiz-intro/
#
# https://www.gcertificationcourse.com/linkedin-python-skill-quiz-answers/
#
# https://learn.microsoft.com/en-us/python/api/overview/azure/storage-file-share-readme?view=azure-python
#
# https://learn.microsoft.com/en-us/rest/api/storageservices/put-blob-from-url?tabs=azure-ad
#
# https://learn.microsoft.com/fr-fr/python/api/overview/azure/storage-blob-readme?view=azure-python
#
# https://stackoverflow.com/questions/51145124/how-to-list-all-blobs-inside-of-a-specific-subdirectory-in-azure-cloud-storage-u

# %%
import numpy as np
import PySimpleGUI as sg
import os
from time import sleep

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

import pandas as pd

import openai
openai.api_key = "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"
# Out:
# /usr/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#sg.theme("DarkBlue15")
#sg.theme("LightGreen1")
sg.theme("reddit")
#sg.theme("DarkTeal2")
#sg.theme("Black")
#sg.theme("TealMono")
#sg.theme("TanBlue")
#sg.theme("Tan")
# Out:
# 'Reddit'

# %%
# ----------------------------------
# Lire des fichiers de mon PC
# ----------------------------------
# fpath = "/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Python"
# fpath = "/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/"
# fpath = "/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/erreurAzure/"
fpath = "/home/oem2/Documents/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure_ENG/"
fpath = "/home/oem2/Documents/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure_week1_ENG/"
listes_de_fichiers = os.listdir(fpath)
# ----------------------------------

# ----------------------------------
# Parce des noms de fichiers
tmp = sorted(listes_de_fichiers)
replace_le = ['out', '.txt']
replace_avec = ['', '']

tmp1 = []
for nom in tmp:
    for ind, i in enumerate(replace_le):
        nom = nom.replace(i, replace_avec[ind])
    tmp1.append(int(nom))
ordd = np.argsort(tmp1)

listes_de_fichiers_sort = [tmp[i] for i in ordd]
listes_de_fichiers_sort
# ----------------------------------
# Out:
# ['out0.txt',
#  'out1.txt',
#  'out2.txt',
#  'out3.txt',
#  'out4.txt',
#  'out5.txt',
#  'out6.txt',
#  'out8.txt',
#  'out13.txt',
#  'out14.txt',
#  'out15.txt',
#  'out16.txt',
#  'out18.txt',
#  'out19.txt',
#  'out20.txt',
#  'out21.txt',
#  'out23.txt',
#  'out36.txt',
#  'out44.txt',
#  'out47.txt',
#  'out51.txt',
#  'out53.txt',
#  'out54.txt',
#  'out56.txt',
#  'out57.txt',
#  'out58.txt',
#  'out59.txt',
#  'out60.txt',
#  'out61.txt',
#  'out62.txt',
#  'out63.txt',
#  'out64.txt',
#  'out69.txt',
#  'out70.txt',
#  'out71.txt',
#  'out72.txt',
#  'out73.txt',
#  'out75.txt',
#  'out76.txt',
#  'out77.txt',
#  'out78.txt',
#  'out79.txt',
#  'out80.txt',
#  'out81.txt',
#  'out84.txt',
#  'out89.txt',
#  'out93.txt',
#  'out98.txt',
#  'out100.txt',
#  'out103.txt',
#  'out104.txt',
#  'out105.txt',
#  'out107.txt',
#  'out108.txt',
#  'out109.txt',
#  'out110.txt',
#  'out111.txt',
#  'out112.txt',
#  'out113.txt',
#  'out114.txt',
#  'out115.txt',
#  'out116.txt',
#  'out118.txt',
#  'out130.txt',
#  'out140.txt',
#  'out157.txt']

# %%
def clean_text(textout):
    to_replace = [";", '\n', '</p>', '<a', 'id=', "href=", 'title=', 'class=', '</a>', 
                  '</sup>', '<p>', '</b>', '<sup', '>', '<', '\\']
    replace_with = ''

    for ind, tr in enumerate(to_replace):
        textout = [i.replace(tr, replace_with) for i in textout]
    return textout

# %% [markdown]
# ## Examen avec ChatGPT

# %%
cnt = 0
gptcnt = 0
SCORE = 0
GPT_SCORE = 0
noms = ['QUESTION', 'REPONSE0', 'REPONSE1', 'REPONSE2', 'REPONSE3', 'vrai_rep']

myres = 0

for ind, nom_de_fichier in enumerate(listes_de_fichiers_sort):
    
    # ----------------------------------
    # Lire des fichiers de mon PC
    # ----------------------------------
    filepath = os.path.join(fpath, nom_de_fichier)

    out = []
    with open(filepath, 'r') as reader:
        out.append(reader.read())
    out = out[0].split('\n')
    out = [i for i in out if any(i)]
    # ----------------------------------
    
    d = dict(zip(noms, out))
      
        
    # ----------------------------------
    prompt = d['QUESTION']
    response = openai.Completion.create(model="text-davinci-003", prompt=prompt, temperature=0.1, 
                                    max_tokens=30, top_p=1, n=1, logprobs=2)
    print('Text response: ', response.choices)
    
    
    df = pd.json_normalize(response.choices)
    d['chatgpt_rep'] = clean_text(df.text.to_numpy())
    print('gpt reponse: ', d['chatgpt_rep'])
    
    # Determiner laquelle est similar à le reponse de chatgpt
    a = ['REPONSE0', 'REPONSE1', 'REPONSE2', 'REPONSE3']
    out = []
    for i in a:
        out.append(fuzz.partial_ratio(d['chatgpt_rep'], d[i]))
    v_ind = np.argmax(out)
    v = a[v_ind]
    d['chatgpt_choix'] = d[v] 
    # ----------------------------------
    
    if ind == len(listes_de_fichiers)-1:
        layout = [[sg.Text(f'Current SCORE: {SCORE}')], 
                  [sg.Text(d['QUESTION'])]]
    else:
        layout = [[sg.Text(f'Q{ind}, MY Current SCORE: {SCORE}, chatgpt: {v_ind+1}, GPTCHAT Score: {GPT_SCORE}')],
                  [sg.Multiline(d['QUESTION'], size=(40,10))],
              [sg.Button(d['REPONSE0'])],  
              [sg.Button(d['REPONSE1'])],
              [sg.Button(d['REPONSE2'])],
              [sg.Button(d['REPONSE3'])]]
    
    # Create the window
    window = sg.Window("DataLogger", layout, margins=(200, 200))
    
    event, values = window.read()
    
    if event == d['REPONSE0'] and d['vrai_rep'] == d['REPONSE0']:  
        cnt = cnt + 1
        myres = d['REPONSE0']
    if event == d['REPONSE1'] and d['vrai_rep'] == d['REPONSE1']:
        cnt = cnt + 1
        myres = d['REPONSE1']
    if event == d['REPONSE2'] and d['vrai_rep'] == d['REPONSE2']:
        cnt = cnt + 1
        myres = d['REPONSE2']
    if event == d['REPONSE3'] and d['vrai_rep'] == d['REPONSE3']:
        cnt = cnt + 1
        myres = d['REPONSE3']
        
    SCORE = cnt/(ind+1) * 100
    
    # ----------------------------------
    
    if d['chatgpt_choix'] == d['REPONSE0'] and d['vrai_rep'] == d['REPONSE0']:
        gptcnt = gptcnt + 1
    if d['chatgpt_choix'] == d['REPONSE1'] and d['vrai_rep'] == d['REPONSE1']:
        gptcnt = gptcnt + 1
    if d['chatgpt_choix'] == d['REPONSE2'] and d['vrai_rep'] == d['REPONSE2']:
        gptcnt = gptcnt + 1
    if d['chatgpt_choix'] == d['REPONSE3'] and d['vrai_rep'] == d['REPONSE3']:
        gptcnt = gptcnt + 1
        
    GPT_SCORE = gptcnt/(ind+1) * 100
    
    # ----------------------------------
    
    print('myres: ', myres)
    print('vrai_rep: ', d['vrai_rep'])
    print('gpt: ', d['chatgpt_choix'])
    print('---------------------------------------')
    
    if myres == 0:
        f = open("resultants.txt", "a")
        f.write(f"{d['QUESTION']}\n{myres}\n{d['vrai_rep']}")
        f.write("\n\n")
        f.close()
        
    myres = 0
    window.close()


sleep(1)  # Wait 10 second
window.close()

# %% [markdown]
# ## Examen Simple

# %%
cnt = 0
SCORE = 0
noms = ['QUESTION', 'REPONSE0', 'REPONSE1', 'REPONSE2', 'REPONSE3', 'vrai_rep']
myres = 0

for ind, nom_de_fichier in enumerate(listes_de_fichiers_sort):
    
    # ----------------------------------
    # Lire des fichiers de mon PC
    # ----------------------------------
    filepath = os.path.join(fpath, nom_de_fichier)

    out = []
    with open(filepath, 'r') as reader:
        out.append(reader.read())
    out = out[0].split('\n')
    out = [i for i in out if any(i)]
    # ----------------------------------
    
    d = dict(zip(noms, out))
    
    if ind == len(listes_de_fichiers)-1:
        layout = [[sg.Text(f'Current SCORE: {SCORE}')], 
                  [sg.Text(d['QUESTION'])]]
    else:
        layout = [[sg.Text(f'Q{ind}, MY Current SCORE: {SCORE}')],
                  [sg.Multiline(d['QUESTION'], size=(40,10))],
              [sg.Button(d['REPONSE0'])],  
              [sg.Button(d['REPONSE1'])],
              [sg.Button(d['REPONSE2'])],
              [sg.Button(d['REPONSE3'])]]
    
    # Create the window
    window = sg.Window("DataLogger", layout, margins=(200, 200))
    
    event, values = window.read()
    
    if event == d['REPONSE0'] and d['vrai_rep'] == d['REPONSE0']:  
        cnt = cnt + 1
        myres = d['REPONSE0']
    if event == d['REPONSE1'] and d['vrai_rep'] == d['REPONSE1']:
        cnt = cnt + 1
        myres = d['REPONSE1']
    if event == d['REPONSE2'] and d['vrai_rep'] == d['REPONSE2']:
        cnt = cnt + 1
        myres = d['REPONSE2']
    if event == d['REPONSE3'] and d['vrai_rep'] == d['REPONSE3']:
        cnt = cnt + 1
        myres = d['REPONSE3']
        
    SCORE = cnt/(ind+1) * 100
    
    print('myres: ', myres)
    print('vrai_rep: ', d['vrai_rep'])
    print('---------------------------------------')
    
    if myres == 0:
        f = open("resultants.txt", "a")
        f.write(f"{d['QUESTION']}\n{myres}\n{d['vrai_rep']}")
        f.write("\n\n")
        f.close()
        
    myres = 0
    window.close()


sleep(1)  # Wait 10 second
window.close()

# %% [markdown]
# # GPT chat help

# %%
def clean_text(textout):
    to_replace = [";", '\n', '</p>', '<a', 'id=', "href=", 'title=', 'class=', '</a>', 
                  '</sup>', '<p>', '</b>', '<sup', '>', '<', '\\']
    replace_with = ''

    for ind, tr in enumerate(to_replace):
        textout = [i.replace(tr, replace_with) for i in textout]
    return textout

# %%
prompt = "Laquel de ces modes n'est P?"


# Temperature : What sampling temperature to use, between 0 and 2. Higher values like 0.8 will make the 
# output more random, while lower values like 0.2 will make it more focused and deterministic. (default=1)

response = openai.Completion.create(model="text-davinci-003", prompt=prompt, temperature=1, 
                                    max_tokens=25, top_p=1, n=10, logprobs=2)
#print('Text response: ', response.choices)

df = pd.json_normalize(response.choices)
textout = clean_text(df.text.to_numpy())
textout
# Out:
# ['Constant values should be named in Python in all uppercase with underscores (namely, SNAKE_',
#  'Constant values in Python should be named in all uppercase letters with underscores used to separate words. For example',
#  'Constant values in Python should be named using all uppercase letters with words separated by underscores. For example:',
#  'Constant values should be named using all uppercase letters with underscores separating words (e.g. MAX_',
#  'Constant values should be named in uppercase letters with underscores between words (e.g. MAX_VALUE',
#  'Constant values should be named in Python using uppercase letters and underscores as word separators (e.g',
#  'Constant values should be named in all uppercase, with words separated by underscores. For example: MY_',
#  'Constant values should be named in all uppercase letters, with words separated by underscores. For example: VAL',
#  'Constant values should be named using all uppercase letters and underscores to separate words, e.g. MAX',
#  'Constant values should be named in all uppercase with underscores between words. For example: MAX_VALUE,']

# %%
file_path = ['/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Azure_cogservices_translate/data1/tmp.txt']

for fichnom in file_path:
    doc_text = []
    with open(fichnom, 'r') as reader:
        doc_text.append(reader.read())
    
    print(doc_text)
    
    response = openai.Completion.create(model="text-davinci-003", prompt=f"{doc_text}", temperature=1, 
                                    max_tokens=25, top_p=1, n=10, logprobs=2)

    df = pd.json_normalize(response.choices)
    textout = clean_text(df.text.to_numpy())
textout
# Out:
# ['With GNU tools such as GNU grep, awk, and sed, what is the difference between basic regular expressions and extended regualr expressions\n']
# ['The main difference between basic and extended regular expressions is that extended regular expressions are more powerful and feature more options than basic',
#  'Basic regular expressions are limited in functionality and are less powerful than extended regular expressions. Basic regular expressions provide basic syntact',
#  'Basic regular expressions, also referred to as BREs, are a more limited form of regular expression. They match characters',
#  'Basic regular expressions (BRE) are the default on most systems and provide basic features for pattern matching. Extended regular expressions',
#  'Basic regular expressions describe a particular sequence of characters, but cannot provide additional information such as metacharacters, repetition',
#  'Basic regular expressions are simpler and more limited in their capabilities. They work by matching a single character from the given string',
#  'Basic regular expressions are less powerful than extended regular expressions, but they are simpler and easier to use. Basic regular expressions',
#  'Basic regular expressions (BRE) are limited and simple, but they allow for extremely rapid searching of a given set of',
#  'Basic regular expressions use simpler syntax that allows you to do basic pattern matching, while extended regular expressions have more complex syntax',
#  'Basic Regular Expressions are the oldest form of regular expressions, they only use special characters as metacharacters.']

# %% [markdown]
# # PLUS

# %%
# PLUS 
file_path = [f'{fpath}{i}' for i in listes_de_fichiers_sort]
file_path
for fichnom in file_path:

    doc_text = []
    with open(fichnom, 'r') as reader:
        doc_text.append(reader.read())
    out = doc_text[0].split("\n")
    out = [i for i in out if any(i)]
    
    f = open(f"{fpath}{fichnom.split(fpath)[1]}", "wt")
    for i in out:
        f.write(f"{i}\n")
    f.close()

# %%
file_path = [f'{fpath}{i}' for i in listes_de_fichiers_sort]
file_path
# Out:
# ['/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out0.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out1.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out2.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out3.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out4.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out5.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out6.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out10.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out11.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out12.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out13.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out14.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out15.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out16.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out17.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out18.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out19.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out20.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out21.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out22.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out23.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out24.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out25.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out27.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out28.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out29.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out32.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out33.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out34.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out35.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out37.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out39.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out40.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out41.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out42.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out43.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out44.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out45.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out46.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out48.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out52.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out53.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out54.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out55.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out56.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out57.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out58.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out59.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out60.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out62.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out63.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out64.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out65.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out66.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out74.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out76.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out78.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out79.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out80.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out81.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out83.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out84.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out86.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out87.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out91.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out92.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out94.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out98.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out99.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out100.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out101.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out102.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out107.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out112.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out113.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out116.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out118.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out130.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out140.txt',
#  '/home/oem2/Documents/PROGRAMMING/Github_analysis_PROJECTS/Créer_des_questionnaires/Q_Azure/out157.txt']

# %%
f = open(f"{fpath}total.txt", "wt")
f.close()

for fichnom in file_path:
    doc_text = []
    with open(fichnom, 'r') as reader:
        doc_text.append(reader.read())
    out = doc_text[0].split("\n")
    out = [i for i in out if any(i)]
    out.append("")
    out.append("")
    out.append("")
    out.append("")
    out.append("")
    
    f = open(f"{fpath}total.txt", "at")
    for i in out:
        f.write(f"{i}\n")
    f.close()
